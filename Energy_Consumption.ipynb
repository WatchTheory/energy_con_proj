# %% [markdown]
# <a href="https://colab.research.google.com/github/WatchTheory/energy_con_proj/blob/main/Energy_Consumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Importing Libraries

# %%
from google.colab import sheets    # importing from google

import pandas as pd
import numpy as n

# %% [markdown]
# ## Convert file to pandas dataframe

# %%
# # Replace with your google sheet's URL
sheet_url = 'https://docs.google.com/spreadsheets/d/1fopq22OhZiR11Fbj4RC5aU_s-RpVQFCV8jxxiT3d450/edit?gid=195630684#gid=195630684'
sheet = sheets.InteractiveSheet(url=sheet_url)            # Create interactive shees with url

# Convert the sheet data to a Pandas DataFrame
df_data = sheet.as_df()

# %%
df_data.head()
# Out:
#    Year Month          Sector Hydroelectric Power Geothermal Energy  \
# 0  1973     1      Commerical                   0                 0
# 1  1973     1  Electric Power                   0              0.49
# 2  1973     1      Industrial                1.04                 0
# 3  1973     1     Residential                   0                 0
# 4  1973     1  Transportation                   0                 0
#
#   Solar Energy Wind Energy Wood Energy Waste Energy  \
# 0            0           0        0.57            0
# 1            0           0       0.054        0.157
# 2            0           0      98.933            0
# 3            0           0      30.074            0
# 4            0           0           0            0
#
#   Fuel Ethanol, Excluding Denaturant Biomass Losses and Co-products  \
# 0                                  0                              0
# 1                                  0                              0
# ...
